# %%
import turtle
t = turtle.Turtle()
#vengoinha
t.fillcolor('gray')
t.begin_fill()
t.forward(60)
t.left(120)
t.forward(60)
t.left(120)
t.forward(60)
t.end_fill()
t.fillcolor('blue')
t.begin_fill()
t.right(240)
t.forward(60)
t.right(90)
t.forward(60)
t.right(90)
t.forward(60)
t.right(90)
t.forward(60)
t.right(90)
t.forward(60)
t.end_fill()
t.fillcolor('gray')
t.begin_fill()
t.left(30)
t.forward(80)
t.left(90)
t.forward(60)
t.left(90)
t.forward(80)
t.left(90)
t.forward(60)
t.end_fill()
t.fillcolor('blue')
t.begin_fill()
t.left(90)
t.forward(80)
t.right(120)
t.forward(60)
t.right(60)
t.forward(80)
t.right(120)
t.forward(60)
t.end_fill()
t.right(90)
#vematroi
t.penup()
t.forward(150)
t.left(90)
t.forward(150)
t.pendown()
t.fillcolor('yellow')
t.begin_fill()
t.circle(30)
t.end_fill()
#vecuachinh
t.penup()
t.left(90)
t.forward(190)
t.left(90)
t.forward(170)
t.pendown()
t.fillcolor('black')
t.begin_fill()
t.forward(40)
t.left(90)
t.forward(20)
t.left(90)
t.forward(40)
t.left(90)
t.forward(20)
t.end_fill()
t.right(180)
t.penup()
t.forward(20)
t.left(30)
t.forward(80)
t.pendown()
#vecuaso
t.fillcolor('white')
t.begin_fill()
t.right(120)
t.forward(20)
t.right(60)
t.forward(20)
t.right(120)
t.forward(20)
t.right(60)
t.forward(20)
t.end_fill()
#vecaicay
t.penup()
t.right(30)
t.forward(200)
t.right(90)
t.forward(100)
t.pendown()
t.fillcolor('brown')
t.begin_fill()
t.right(90)
t.forward(30)
t.right(90)
t.forward(80)
t.right(90)
t.forward(30)
t.right(90)
t.forward(80)
t.end_fill()
#vechumla1
t.right(180)
t.forward(80)
t.fillcolor('green')
t.begin_fill()
t.right(90)
t.forward(30)
t.left(120)
t.forward(90)
t.left(120)
t.forward(90)
t.left(120)
t.forward(90)
t.end_fill()
#vechumla2
t.penup()
t.left(90)
t.forward(78)
t.left(90)
t.forward(15)
t.pendown()
t.fillcolor('green')
t.begin_fill()
t.right(60)
t.forward(60)
t.left(120)
t.forward(60)
t.left(120)
t.forward(60)
t.end_fill()
#vechumla3
t.penup()
t.left(90)
t.forward(52)
t.left(90)
t.forward(10)
t.pendown()
t.fillcolor('green')
t.begin_fill()
t.right(60)
t.forward(40)
t.left(120)
t.forward(40)
t.left(120)
t.forward(40)
t.end_fill()
turtle.done()
